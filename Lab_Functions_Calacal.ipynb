# %%
# [CELL 1] STUDENT CONFIGURATION

LAST_NAME = "Calacal"
STUDENT_ID = "TUPM-25-0546"

SEED_DIGIT = int(STUDENT_ID[-1])
ID_SUM = sum(int(d) for d in STUDENT_ID if d.isdigit())
NAME_LENGTH = len(LAST_NAME)

print("Student:", LAST_NAME)
print("Seed Digit:", SEED_DIGIT)
print("Digit Sum:", ID_SUM)
print("Surname Length:", NAME_LENGTH)
# Out:
# Student: Calacal
# Seed Digit: 6
# Digit Sum: 22
# Surname Length: 7

# %%
# [CELL 2] FUNCTIONAL ENCAPSULATION

def greet():
    print("=" * 40)
    print(f"System Initialized for: {LAST_NAME}")
    print("" * 40)

def identity_code():
    code = SEED_DIGIT * NAME_LENGTH
    return code
greet()
print("Identify Code:", identity_code())
# Out:
# ========================================
# System Initialized for: Calacal
#
# Identify Code: 42

# %%
# [CELL 3] LEGB VALIDATION

global_value = ID_SUM

def scope_test():
    global_value = SEED_DIGIT
    print("Inside function:", global_value)

scope_test()
print("Outside function:", global_value)
# Out:
# Inside function: 6
# Outside function: 22

# %%
# [CELL 4] PARAMETRIC PROCESSING

def user_summary(title, *scores, **info):
    print(f"=== (title) ===")

    total = sum(scores)
    average = total / len(scores)

    print("Scores:", scores)
    print("Total:", scores)
    print("Average:", round(average,2))

    for k,v in info.items():
        print(f"{k}: {v}")

    return average

avg = user_summary(
    f"{LAST_NAME} Academic Report",
    SEED_DIGIT * 10,
    ID_SUM % 100,
    NAME_LENGTH * 5,
    id=STUDENT_ID,
    surname=LAST_NAME
)
# Out:
# === (title) ===
# Scores: (60, 22, 35)
# Total: (60, 22, 35)
# Average: 39.0
# id: TUPM-25-0546
# surname: Calacal

# %%
# [CELL 5] RETURN MECHANISM

def compute_area(radius):
    return 3.1416 * radius**2

area = compute_area(SEED_DIGIT + 2)
print("Computed Area:", round(area,2))
# Out:
# Computed Area: 201.06

# %%
# [CELL 6] SAFE CALCULATOR

def safe_calculator(x, y):
    try:
        result = x / y
    except ZeroDivisionError:
        result = "UNDEFINED"
    return result

print("Calculation Result:", safe_calculator(ID_SUM, SEED_DIGIT))
# Out:
# Calculation Result: 3.6666666666666665

# %%
# {CELL 7} RECURSION

def factorial(n):
    if n <= 1:
        return 1
    return n * factorial(n-1)

print("Factorial Result:", factorial(SEED_DIGIT))
# Out:
# Factorial Result: 720

# %%
# [CELL 8] STRING RECURSION

def reverse(text):
    if len(text) <= 1:
        return text
    return text[-1] + reverse(text[:-1])
    
print("Reversed Surname:", reverse(LAST_NAME.upper()))
# Out:
# Reversed Surname: LACALAC

# %%
# [CELL 9] DECORATOR

def logger(func):
    def wrapper(*args, **kwargs):
        print("Executing:", func.__name__)
        return func(*args, **kwargs)
    return wrapper

@logger
def multiply(x, y):
    return x * y

print("Multiplication:", multiply(SEED_DIGIT, NAME_LENGTH))
# Out:
# Executing: multiply
# Multiplication: 42

# %%
# [CELL 10] LAMBDA

data = list(range(1, SEED_DIGIT + 10))
squared = list(map(lambda x: x**2, data))

print("Squared Data:", squared)
# Out:
# Squared Data: [1, 4, 9, 16, 25, 36, 49, 64, 81, 100, 121, 144, 169, 196, 225]

# %%
# [CELL 11] GENERATOR

def even_squares(limit):
    for i in range(limit):
        yield i**2

for value in even_squares(NAME_LENGTH + SEED_DIGIT):
    print(value)
# Out:
# 0
# 1
# 4
# 9
# 16
# 25
# 36
# 49
# 64
# 81
# 100
# 121
# 144

# %%
# grades.py

def compute_average(scores):
    return sum(scores) / len(scores)

def assign_grade(avg):
    if avg >= 90:
        return "A"
    elif avg >= 80:
        return "B"
    elif avg >= 70:
        return "C"
    elif avg >= 60:
        return "D"
    else:
        return "F" 
    
    def generate_remark(grade): 
        remarks = {
            "A": "Excellent Performance", 
            "B": "Good Performance",
            "C": "Satisfactory Performance",
            "D": "Needs Improvement",
            "F": "Failing Status"
        } 
        return remarks.get(grade, "Invalid Grade")

# %%
# grades.py

def compute_average(scores):
    return sum(scores) / len(scores)

def assign_grade(avg):
    if avg >= 90:
        return "A"
    elif avg >= 80:
        return "B"
    elif avg >= 70:
        return "C"
    elif avg >= 60:
        return "D"
    else:
        return "F"

def generate_remark(grade):
    remarks = {
        "A": "Excellent Performance",
        "B": "Good Performance",
        "C": "Satisfactory Performance",
        "D": "Needs Improvement",
        "F": "Failing Status"
    }
    return remarks.get(grade, "Invalid Grade")

# %%
# grades.py

def compute_average(scores):
    return sum(scores) / len(scores)


def assign_grade(avg):
    if avg >= 90:
        return "A"
    elif avg >= 80:
        return "B"
    elif avg >= 70:
        return "C"
    elif avg >= 60:
        return "D"
    else:
        return "F"


def generate_remark(grade):
    remarks = {
        "A": "Excellent Performance",
        "B": "Good Performance",
        "C": "Satisfactory Performance",
        "D": "Needs Improvement",
        "F": "Failing Status"
    }
    return remarks.get(grade, "Invalid Grade")

# %%
# grades.py

def compute_average(scores):
    if not scores:
        return 0
    return sum(scores) / len(scores)

def assign_grade(avg):  # Ensure this is NOT indented
    if avg >= 90:
        return "A"
    elif avg >= 80:
        return "B"
    elif avg >= 70:
        return "C"
    elif avg >= 60:
        return "D"
    else:
        return "F" 

def generate_remark(grade):  # Ensure this is NOT indented
    remarks = {
        "A": "Excellent Performance", 
        "B": "Good Performance",
        "C": "Satisfactory Performance",
        "D": "Needs Improvement",
        "F": "Failing Status"
    } 
    return remarks.get(grade, "Invalid Grade")

# %%
# main.py

import importlib
import grades
importlib.reload(grades) # This forces the fresh code to load

# Student Identity Configuration
LAST_NAME = "Calacal"
STUDENT_ID = "TUPM-25-0546"

SEED_DIGIT = int(STUDENT_ID[-1])
ID_SUM = sum(int(d) for d in STUDENT_ID if d.isdigit())
NAME_LENGTH = len(LAST_NAME)

scores = [
    SEED_DIGIT * 10,
    ID_SUM % 100,
    NAME_LENGTH * 7
]

average = grades.compute_average(scores)
grade = grades.assign_grade(avg)
remark = grades.generate_remark(grade)

print("=" * 40)
print(f"Student ID: {LAST_NAME}")
print(f"Student ID: {STUDENT_ID}")
print(f"Generated Scores: {scores}")
print(f"Average: {round(average,2)}")
print(f"Grade: {grade}")
print(f"Remark: {remark}")
print("=" * 40)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 22
#      15 scores = [
#      16     SEED_DIGIT * 10,
#      17     ID_SUM % 100,
#      18     NAME_LENGTH * 7
#      19 ]
#      21 average = grades.compute_average(scores)
# ---> 22 grade = grades.assign_grade(avg)
#      23 remark = grades.generate_remark(grade)
#      25 print("=" * 40)
#
# AttributeError: module 'grades' has no attribute 'assign_grade'
